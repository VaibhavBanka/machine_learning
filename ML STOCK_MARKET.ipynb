# %%
import numpy as np 
import pandas as pd 
import os 
import matplotlib.pyplot as plt 
import warnings
warnings.filterwarnings('ignore')
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15, 6

# %%
display(os.getcwd())
# Out:
# 'C:\\Users\\dell'

# %%
os.chdir ('C:\\Users\\dell\\Desktop\\stock market price predict')
display (os.getcwd())
# Out:
# 'C:\\Users\\dell\\Desktop\\stock market price predict'

# %%
df =pd.read_csv("prices.csv", header=0)
display (df)
# Out:
#                     date symbol        open       close         low  \
# 0             05-01-2016   WLTW  123.430000  125.839996  122.309998
# 1             06-01-2016   WLTW  125.239998  119.980003  119.940002
# 2             07-01-2016   WLTW  116.379997  114.949997  114.930000
# 3             08-01-2016   WLTW  115.480003  116.620003  113.500000
# 4             09-01-2016   WLTW  117.010002  114.970001  114.089996
# ...                  ...    ...         ...         ...         ...
# 851259        30-12-2016    ZBH  103.309998  103.199997  102.849998
# 851260        30-12-2016   ZION   43.070000   43.040001   42.689999
# 851261        30-12-2016    ZTS   53.639999   53.529999   53.270000
# 851262  30-12-2016 00:00    AIV   44.730000   45.450001   44.410000
# 851263  30-12-2016 00:00    FTV   54.200001   53.630001   53.389999
#
#               high   volume
# 0       126.250000  2163600
# 1       125.540001  2386400
# 2       119.739998  2489500
# 3       117.440002  2006300
# 4       117.330002  1408600
# ...            ...      ...
# 851259  103.930000   973800
# 851260   43.310001  1938100
# 851261   53.740002  1701200
# 851262   45.590000  1380900
# 851263   54.480000   705100
#
# [851264 rows x 7 columns]

# %%
print(df.shape)
# Out:
# (851264, 7)

# %%
print(df.columns)
# Out:
# Index(['date', 'symbol', 'open', 'close', 'low', 'high', 'volume'], dtype='object')

# %%
df.symbol.value_counts()
# Out:
# KSU     1762
# NOC     1762
# ORCL    1762
# OMC     1762
# OKE     1762
#         ...
# KHC      378
# HPE      304
# CSRA     284
# WLTW     251
# FTV      126
# Name: symbol, Length: 501, dtype: int64

# %%
df.symbol.unique()
# Out:
# array(['WLTW', 'A', 'AAL', 'AAP', 'AAPL', 'ABC', 'ABT', 'ACN', 'ADBE',
#        'ADI', 'ADM', 'ADP', 'ADS', 'ADSK', 'AEE', 'AEP', 'AES', 'AET',
#        'AFL', 'AGN', 'AIG', 'AIZ', 'AJG', 'AKAM', 'ALB', 'ALK', 'ALL',
#        'ALXN', 'AMAT', 'AME', 'AMG', 'AMGN', 'AMP', 'AMT', 'AMZN', 'AN',
#        'ANTM', 'AON', 'APA', 'APC', 'APD', 'APH', 'ARNC', 'ATVI', 'AVB',
#        'AVGO', 'AVY', 'AWK', 'AXP', 'AYI', 'AZO', 'BA', 'BAC', 'BAX',
#        'BBBY', 'BBT', 'BBY', 'BCR', 'BDX', 'BEN', 'BHI', 'BIIB', 'BK',
#        'BLK', 'BLL', 'BMY', 'BSX', 'BWA', 'BXP', 'C', 'CA', 'CAG', 'CAH',
#        'CAT', 'CB', 'CBG', 'CBS', 'CCI', 'CCL', 'CELG', 'CERN', 'CF',
#        'CHD', 'CHK', 'CHRW', 'CI', 'CINF', 'CL', 'CLX', 'CMA', 'CMCSA',
#        'CME', 'CMG', 'CMI', 'CMS', 'CNC', 'CNP', 'COF', 'COG', 'COH',
#        'COL', 'COO', 'COP', 'COST', 'CPB', 'CRM', 'CSCO', 'CSX', 'CTAS',
#        'CTL', 'CTSH', 'CTXS', 'CVS', 'CVX', 'CXO', 'D', 'DAL', 'DD', 'DE',
#        'DFS', 'DG', 'DGX', 'DHI', 'DHR', 'DIS', 'DISCA', 'DISCK', 'DLR',
#        'DLTR', 'DNB', 'DOV', 'DOW', 'DPS', 'DRI', 'DTE', 'DUK', 'DVA',
#        'DVN', 'EA', 'EBAY', 'ECL', 'ED', 'EFX', 'EIX', 'EL', 'EMN', 'EMR',
#        'ENDP', 'EOG', 'EQIX', 'EQR', 'EQT', 'ES', 'ESRX', 'ESS', 'ETFC',
#        'ETN', 'ETR', 'EW', 'EXC', 'EXPD', 'EXPE', 'EXR', 'F', 'FAST',
#        'FCX', 'FDX', 'FE', 'FFIV', 'FIS', 'FISV', 'FITB', 'FL', 'FLIR',
#        'FLR', 'FLS', 'FMC', 'FOX', 'FOXA', 'FRT', 'FSLR', 'FTI', 'FTR',
#        'GD', 'GE', 'GGP', 'GILD', 'GIS', 'GLW', 'GOOG', 'GOOGL', 'GPC',
#        'GPN', 'GPS', 'GRMN', 'GS', 'GT', 'GWW', 'HAL', 'HAR', 'HAS',
#        'HBAN', 'HBI', 'HCN', 'HCP', 'HD', 'HES', 'HIG', 'HOG', 'HOLX',
#        'HON', 'HP', 'HPQ', 'HRB', 'HRL', 'HRS', 'HSIC', 'HST', 'HSY',
#        'HUM', 'IBM', 'ICE', 'IDXX', 'IFF', 'ILMN', 'INTC', 'INTU', 'IP',
#        'IPG', 'IR', 'IRM', 'ISRG', 'ITW', 'IVZ', 'JBHT', 'JCI', 'JEC',
#        'JNJ', 'JNPR', 'JPM', 'JWN', 'K', 'KEY', 'KIM', 'KLAC', 'KMB',
#        'KMX', 'KO', 'KR', 'KSS', 'KSU', 'L', 'LB', 'LEG', 'LEN', 'LH',
#        'LKQ', 'LLL', 'LLTC', 'LLY', 'LMT', 'LNC', 'LNT', 'LOW', 'LRCX',
#        'LUK', 'LUV', 'LVLT', 'M', 'MA', 'MAA', 'MAC', 'MAR', 'MAS', 'MAT',
#        'MCD', 'MCHP', 'MCK', 'MCO', 'MDLZ', 'MDT', 'MET', 'MHK', 'MJN',
#        'MKC', 'MLM', 'MMC', 'MMM', 'MNST', 'MO', 'MON', 'MOS', 'MRK',
#        'MRO', 'MSFT', 'MSI', 'MTB', 'MTD', 'MU', 'MUR', 'MYL', 'NBL',
#        'NDAQ', 'NEE', 'NEM', 'NFLX', 'NFX', 'NI', 'NKE', 'NOC', 'NOV',
#        'NRG', 'NSC', 'NTAP', 'NTRS', 'NUE', 'NVDA', 'NWL', 'O', 'OKE',
#        'OMC', 'ORCL', 'ORLY', 'OXY', 'PAYX', 'PBCT', 'PBI', 'PCAR', 'PCG',
#        'PCLN', 'PDCO', 'PEG', 'PEP', 'PFE', 'PFG', 'PG', 'PGR', 'PH',
#        'PHM', 'PKI', 'PLD', 'PM', 'PNC', 'PNR', 'PNW', 'PPG', 'PPL',
#        'PRGO', 'PRU', 'PSA', 'PVH', 'PWR', 'PX', 'PXD', 'QCOM', 'R',
#        'RAI', 'RCL', 'REGN', 'RF', 'RHI', 'RHT', 'RIG', 'RL', 'ROK',
#        'ROP', 'ROST', 'RRC', 'RSG', 'RTN', 'SBUX', 'SCG', 'SCHW', 'SE',
#        'SEE', 'SHW', 'SIG', 'SJM', 'SLB', 'SLG', 'SNA', 'SNI', 'SO',
#        'SPG', 'SPGI', 'SPLS', 'SRCL', 'SRE', 'STI', 'STT', 'STX', 'STZ',
#        'SWK', 'SWKS', 'SWN', 'SYK', 'SYMC', 'SYY', 'T', 'TAP', 'TDC',
#        'TEL', 'TGNA', 'TGT', 'TIF', 'TJX', 'TMK', 'TMO', 'TROW', 'TRV',
#        'TSCO', 'TSN', 'TSO', 'TSS', 'TWX', 'TXN', 'TXT', 'UAA', 'UAL',
#        'UDR', 'UHS', 'ULTA', 'UNH', 'UNM', 'UNP', 'UPS', 'URBN', 'URI',
#        'USB', 'UTX', 'V', 'VAR', 'VFC', 'VIAB', 'VLO', 'VMC', 'VNO',
#        'VRSK', 'VRSN', 'VRTX', 'VTR', 'VZ', 'WAT', 'WBA', 'WDC', 'WEC',
#        'WFC', 'WFM', 'WHR', 'WM', 'WMB', 'WMT', 'WU', 'WY', 'WYN', 'WYNN',
#        'XEC', 'XEL', 'XL', 'XLNX', 'XOM', 'XRAY', 'XRX', 'YHOO', 'YUM',
#        'ZBH', 'ZION', 'AIV', 'CHTR', 'LYB', 'GM', 'ABBV', 'DLPH', 'FB',
#        'FBHS', 'HCA', 'KMI', 'KORS', 'MPC', 'NLSN', 'PSX', 'TDG', 'TRIP',
#        'XYL', 'ZTS', 'COTY', 'MNK', 'NWS', 'NWSA', 'EVHC', 'ALLE', 'CFG',
#        'NAVI', 'QRVO', 'SYF', 'WRK', 'KHC', 'PYPL', 'HPE', 'CSRA', 'FTV'],
#       dtype=object)

# %%
df.symbol.unique()[0:20]
# Out:
# array(['WLTW', 'A', 'AAL', 'AAP', 'AAPL', 'ABC', 'ABT', 'ACN', 'ADBE',
#        'ADI', 'ADM', 'ADP', 'ADS', 'ADSK', 'AEE', 'AEP', 'AES', 'AET',
#        'AFL', 'AGN'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 851264 entries, 0 to 851263
# Data columns (total 7 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   date    851264 non-null  object
#  1   symbol  851264 non-null  object
#  2   open    851264 non-null  float64
#  3   close   851264 non-null  float64
#  4   low     851264 non-null  float64
#  5   high    851264 non-null  float64
#  6   volume  851264 non-null  int64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 45.5+ MB

# %%
df.describe()
# Out:
#                 open          close            low           high  \
# count  851264.000000  851264.000000  851264.000000  851264.000000
# mean       70.836986      70.857109      70.118414      71.543476
# std        83.695876      83.689686      82.877294      84.465504
# min         0.850000       0.860000       0.830000       0.880000
# 25%        33.840000      33.849998      33.480000      34.189999
# 50%        52.770000      52.799999      52.230000      53.310001
# 75%        79.879997      79.889999      79.110001      80.610001
# max      1584.439941    1578.130005    1549.939941    1600.930054
#
#              volume
# count  8.512640e+05
# mean   5.415113e+06
# std    1.249468e+07
# min    0.000000e+00
# 25%    1.221500e+06
# 50%    2.476250e+06
# 75%    5.222500e+06
# max    8.596434e+08

# %%
df.isnull().sum()
# Out:
# date      0
# symbol    0
# open      0
# close     0
# low       0
# high      0
# volume    0
# dtype: int64

# %%
df.date.unique()
# Out:
# array(['05-01-2016', '06-01-2016', '07-01-2016', ..., '28-12-2016 00:00',
#        '29-12-2016 00:00', '30-12-2016 00:00'], dtype=object)

# %%
pd.DataFrame(df.date.unique())
# Out:
#                      0
# 0           05-01-2016
# 1           06-01-2016
# 2           07-01-2016
# 3           08-01-2016
# 4           09-01-2016
# ...                ...
# 4672  23-12-2016 00:00
# 4673  27-12-2016 00:00
# 4674  28-12-2016 00:00
# 4675  29-12-2016 00:00
# 4676  30-12-2016 00:00
#
# [4677 rows x 1 columns]

# %%
df.duplicated().sum()
# Out:
# 0

# %%
comp_info = pd.read_csv('securities.csv')
comp_info
# Out:
#     Ticker symbol                Security SEC filings             GICS Sector  \
# 0             MMM              3M Company     reports             Industrials
# 1             ABT     Abbott Laboratories     reports             Health Care
# 2            ABBV                  AbbVie     reports             Health Care
# 3             ACN           Accenture plc     reports  Information Technology
# 4            ATVI     Activision Blizzard     reports  Information Technology
# ..            ...                     ...         ...                     ...
# 500          YHOO              Yahoo Inc.     reports  Information Technology
# 501           YUM         Yum! Brands Inc     reports  Consumer Discretionary
# 502           ZBH  Zimmer Biomet Holdings     reports             Health Care
# 503          ZION           Zions Bancorp     reports              Financials
# 504           ZTS                  Zoetis     reports             Health Care
#
#                   GICS Sub Industry   Address of Headquarters  \
# 0          Industrial Conglomerates       St. Paul, Minnesota
# 1             Health Care Equipment   North Chicago, Illinois
# 2                   Pharmaceuticals   North Chicago, Illinois
# 3    IT Consulting & Other Services           Dublin, Ireland
# 4       Home Entertainment Software  Santa Monica, California
# ..                              ...                       ...
# 500    Internet Software & Services     Sunnyvale, California
# 501                     Restaurants      Louisville, Kentucky
# 502           Health Care Equipment           Warsaw, Indiana
# 503                  Regional Banks      Salt Lake City, Utah
# 504                 Pharmaceuticals  Florham Park, New Jersey
#
#     Date first added      CIK
# 0                NaN    66740
# 1         31-03-1964     1800
# 2         31-12-2012  1551152
# 3         06-07-2011  1467373
# 4         31-08-2015   718877
# ..               ...      ...
# 500              NaN  1011006
# 501       06-10-1997  1041061
# 502              NaN  1136869
# 503              NaN   109380
# 504       21-06-2013  1555280
#
# [505 rows x 8 columns]

# %%
comp_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 505 entries, 0 to 504
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Ticker symbol            505 non-null    object
#  1   Security                 505 non-null    object
#  2   SEC filings              505 non-null    object
#  3   GICS Sector              505 non-null    object
#  4   GICS Sub Industry        505 non-null    object
#  5   Address of Headquarters  505 non-null    object
#  6   Date first added         307 non-null    object
#  7   CIK                      505 non-null    int64
# dtypes: int64(1), object(7)
# memory usage: 31.7+ KB

# %%
comp_info.isnull().sum()
# Out:
# Ticker symbol                0
# Security                     0
# SEC filings                  0
# GICS Sector                  0
# GICS Sub Industry            0
# Address of Headquarters      0
# Date first added           198
# CIK                          0
# dtype: int64

# %%
comp_info.describe()
# Out:
#                 CIK
# count  5.050000e+02
# mean   7.074490e+05
# std    5.144375e+05
# min    1.800000e+03
# 25%    8.631200e+04
# 50%    8.310010e+05
# 75%    1.075531e+06
# max    1.659166e+06

# %%
comp_info.loc[comp_info.Security.str.startswith('Face') , :]
# Out:
#     Ticker symbol  Security SEC filings             GICS Sector  \
# 181            FB  Facebook     reports  Information Technology
#
#                 GICS Sub Industry Address of Headquarters Date first added  \
# 181  Internet Software & Services  Menlo Park, California       23-12-2013
#
#          CIK
# 181  1326801

# %%
comp_plot = comp_info.loc[(comp_info["Security"] == 'Yahoo Inc.') | (comp_info["Security"] == 'Xerox Corp.') | (comp_info["Security"] == 'Adobe Systems Inc')
              | (comp_info["Security"] == 'Microsoft Corp.') | (comp_info["Security"] == 'Adobe Systems Inc') 
              | (comp_info["Security"] == 'Facebook') | (comp_info["Security"] == 'Goldman Sachs Group') , ["Ticker symbol"] ]["Ticker symbol"] 
print(comp_plot)
# Out:
# 6      ADBE
# 181      FB
# 212      GS
# 306    MSFT
# 496     XRX
# 500    YHOO
# Name: Ticker symbol, dtype: object

# %%
def plotter(code):
    global closing_stock ,opening_stock
    f, axs = plt.subplots(2,2,figsize=(15,8))
    plt.subplot(212)
    company = df[df['symbol']==code]
    company = company.open.values.astype('float32')
    company = company.reshape(-1, 1)
    opening_stock = company
    plt.grid(True)
    plt.xlabel('Time')
    plt.ylabel(code + " open stock prices") 
    plt.title('prices Vs Time')
    plt.plot(company , 'g')
    plt.subplot(211)
    company_close = df[df['symbol']==code]
    company_close = company_close.close.values.astype('float32')
    company_close = company_close.reshape(-1, 1)
    closing_stock = company_close
    plt.xlabel('Time')
    plt.ylabel(code + " close stock prices")
    plt.title('prices Vs Time')
    plt.grid(True)
    plt.plot(company_close , 'b')
    plt.show()

# %%
for i in comp_plot:
    plotter(i)

# %%
for i in comp_plot:
    stocks= np.array (df[df.symbol.isin ([i])].close)
    #print(i,'\n',stocks)
    stocks = stocks.reshape(len(stocks) , 1)
    from sklearn.preprocessing import MinMaxScaler
    scaler = MinMaxScaler(feature_range=(0, 1)) 
    stocks = scaler.fit_transform(stocks) 
    display (stocks)
    train = int(len(stocks) * 0.80)
    test = len(stocks) - train
    train = stocks[0:train]
    display (train.shape)
    #print('\n',train,'\n')
    test = stocks[len(train) : ]
    display(test.shape)
    #print('\n',test,'\n')
    def process_data(data , n_features):
        dataX, dataY = [], []
        for i in range(len(data)-n_features):
            a = data[i:(i+n_features), 0]
            dataX.append(a) 
            dataY.append(data[i + n_features, 0])
        return np.array(dataX), np.array(dataY)
    n_features = 2
    trainX, trainY = process_data(train, n_features)
    testX, testY = process_data(test, n_features)
    stocksX, stocksY = process_data(stocks, n_features)
    trainX = trainX.reshape(trainX.shape[0] , 1 ,trainX.shape[1])
    testX = testX.reshape(testX.shape[0] , 1 ,testX.shape[1])
    stocksX= stocksX.reshape(stocksX.shape[0] , 1 ,stocksX.shape[1])
    import math 
    from keras.models import Sequential 
    from keras.layers import Dense , BatchNormalization , Dropout , Activation 
    from keras.layers import LSTM , GRU 
    from sklearn.preprocessing import MinMaxScaler  
    from sklearn.metrics import mean_squared_error 
    from tensorflow.keras.optimizers import Adam , SGD , RMSprop
    filepath="stock_weights1.hdf5"
    from keras.callbacks import ReduceLROnPlateau , ModelCheckpoint
    lr_reduce = ReduceLROnPlateau(monitor='val_loss', factor=0.1, epsilon=0.0001, patience=1, verbose=1)
    checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='max')
    model = Sequential() 
    model.add(GRU(256 , input_shape = (1 , n_features) , return_sequences=True))
    model.add(Dropout(0.4))
    model.add(LSTM(256))
    model.add(Dropout(0.4)) 
    model.add(Dense(64 ,  activation = 'relu')) 
    model.add(Dense(1))
    #print('Summary\n',model.summary(),'\n')
    model.compile(loss='mean_squared_error', optimizer=Adam(lr = 0.0005) , metrics = ['mean_squared_error'])
    history=model.fit(trainX,trainY,epochs=100,batch_size=128,callbacks=[checkpoint,lr_reduce],validation_data=(testX,testY))
    test_pred = model.predict(testX)
    #display (test_pred [:10])
    test_pred = scaler.inverse_transform(test_pred)
    #display (test_pred [:10])
    testY = testY.reshape(testY.shape[0] , 1)
    testY = scaler.inverse_transform(testY)
    #display (testY[:10])
    from sklearn.metrics import r2_score
    r2_score(testY,test_pred)
    print("Red - Predicted Stock Prices  ,  Blue - Actual Stock Prices")
    plt.rcParams["figure.figsize"] = (15,7)
    plt.plot(testY , 'b')
    plt.plot(test_pred , 'r')
    plt.xlabel('Time')
    plt.ylabel('Stock Prices') 
    plt.title('Check the accuracy of the model with time') 
    plt.grid(True)
    plt.show()
    train_pred = model.predict(trainX)
    train_pred = scaler.inverse_transform(train_pred)
    trainY = trainY.reshape(trainY.shape[0] , 1)
    trainY = scaler.inverse_transform(trainY)
    print ('Display Accuracy Training Data')
    display (r2_score(trainY,train_pred))
    print("Red - Predicted Stock Prices  ,  Blue - Actual Stock Prices")
    plt.rcParams["figure.figsize"] = (15,7)
    plt.plot(trainY  , 'b')
    plt.plot(train_pred, 'r')
    plt.xlabel('Time')
    plt.ylabel('Stock Prices')
    plt.title('Check the accuracy of the model with time')
    plt.grid(True)
    plt.show()
    stocks_pred = model.predict(stocksX)
    stocks_pred = scaler.inverse_transform(stocks_pred)
    stocksY = stocksY.reshape(stocksY.shape[0] , 1)
    stocksY = scaler.inverse_transform(stocksY)
    print ('Display Accuracy Training Data')
    display (r2_score(stocksY,stocks_pred))
    results= df[df.symbol.isin ([i])]
    results= results [2:]
    results = results.reset_index(drop=True)
    df_stocks_pred= pd.DataFrame(stocks_pred, columns = ['Close_Prediction'])
    results= pd.concat([results,df_stocks_pred],axis =1)
    results.to_excel('results.xlsx')
    display(results)
# Out:
# array([[0.16341352],
#        [0.17033591],
#        [0.16942804],
#        ...,
#        [0.92010893],
#        [0.91908763],
#        [0.91080344]])
# (1409, 1)
# (353, 1)
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0839 - mean_squared_error: 0.0839
# Epoch 1: val_loss improved from -inf to 0.38451, saving model to stock_weights1.hdf5
# 11/11 [==============================] - 14s 282ms/step - loss: 0.0839 - mean_squared_error: 0.0839 - val_loss: 0.3845 - val_mean_squared_error: 0.3845 - lr: 5.0000e-04
# Epoch 2/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0303 - mean_squared_error: 0.0303
# Epoch 2: val_loss did not improve from 0.38451
# 11/11 [==============================] - 1s 57ms/step - loss: 0.0287 - mean_squared_error: 0.0287 - val_loss: 0.0474 - val_mean_squared_error: 0.0474 - lr: 5.0000e-04
# Epoch 3/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0142 - mean_squared_error: 0.0142
# Epoch 3: val_loss did not improve from 0.38451
# 11/11 [==============================] - 1s 66ms/step - loss: 0.0142 - mean_squared_error: 0.0142 - val_loss: 0.0242 - val_mean_squared_error: 0.0242 - lr: 5.0000e-04
# Epoch 4/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0071 - mean_squared_error: 0.0071
# Epoch 4: val_loss did not improve from 0.38451
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 5.0000002374872565e-05.
# 11/11 [==============================] - 1s 57ms/step - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0337 - val_mean_squared_error: 0.0337 - lr: 5.0000e-04
# Epoch 5/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0048 - mean_squared_error: 0.0048
# Epoch 5: val_loss did not improve from 0.38451
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 5.000000237487257e-06.
# 11/11 [==============================] - 1s 58ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0267 - val_mean_squared_error: 0.0267 - lr: 5.0000e-05
# Epoch 6/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0043 - mean_squared_error: 0.0043
# Epoch 6: val_loss did not improve from 0.38451
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 5.000000328436726e-07.
# 11/11 [==============================] - 1s 60ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0258 - val_mean_squared_error: 0.0258 - lr: 5.0000e-06
# Epoch 7/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0043 - mean_squared_error: 0.0043
# Epoch 7: val_loss did not improve from 0.38451
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 5.000000555810402e-08.
# 11/11 [==============================] - 1s 59ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 5.0000e-07
# Epoch 8/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0045 - mean_squared_error: 0.0045
# Epoch 8: val_loss did not improve from 0.38451
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 5.000000413701855e-09.
# 11/11 [==============================] - 1s 59ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 5.0000e-08
# Epoch 9/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0043 - mean_squared_error: 0.0043
# Epoch 9: val_loss did not improve from 0.38451
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 5.000000413701855e-10.
# 11/11 [==============================] - 1s 59ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 5.0000e-09
# Epoch 10/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0043 - mean_squared_error: 0.0043
# Epoch 10: val_loss did not improve from 0.38451
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 5.000000413701855e-11.
# 11/11 [==============================] - 1s 57ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 5.0000e-10
# Epoch 11/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0043 - mean_squared_error: 0.0043
# Epoch 11: val_loss did not improve from 0.38451
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 5.000000413701855e-12.
# 11/11 [==============================] - 1s 61ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 5.0000e-11
# Epoch 12/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 12: val_loss did not improve from 0.38451
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 5.000000413701855e-13.
# 11/11 [==============================] - 1s 60ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 5.0000e-12
# Epoch 13/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 13: val_loss did not improve from 0.38451
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 5.0000005221220725e-14.
# 11/11 [==============================] - 1s 61ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 5.0000e-13
# Epoch 14/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 14: val_loss did not improve from 0.38451
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 5.000000589884709e-15.
# 11/11 [==============================] - 1s 60ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 5.0000e-14
# Epoch 15/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0045 - mean_squared_error: 0.0045
# Epoch 15: val_loss did not improve from 0.38451
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 5.000000759291298e-16.
# 11/11 [==============================] - 1s 59ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 5.0000e-15
# Epoch 16/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 16: val_loss did not improve from 0.38451
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 5.000000547533061e-17.
# 11/11 [==============================] - 1s 59ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 5.0000e-16
# Epoch 17/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0042 - mean_squared_error: 0.0042
# Epoch 17: val_loss did not improve from 0.38451
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 5.000000415184163e-18.
# 11/11 [==============================] - 1s 60ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 5.0000e-17
# Epoch 18/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 18: val_loss did not improve from 0.38451
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 5.000000332466102e-19.
# 11/11 [==============================] - 1s 60ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 5.0000e-18
# Epoch 19/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0043 - mean_squared_error: 0.0043
# Epoch 19: val_loss did not improve from 0.38451
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 5.000000229068525e-20.
# 11/11 [==============================] - 1s 59ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 5.0000e-19
# Epoch 20/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0043 - mean_squared_error: 0.0043
# Epoch 20: val_loss did not improve from 0.38451
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 5.00000016444504e-21.
# 11/11 [==============================] - 1s 59ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 5.0000e-20
# Epoch 21/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0043 - mean_squared_error: 0.0043
# Epoch 21: val_loss did not improve from 0.38451
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 5.000000245224397e-22.
# 11/11 [==============================] - 1s 68ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 5.0000e-21
# Epoch 22/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0045 - mean_squared_error: 0.0045
# Epoch 22: val_loss did not improve from 0.38451
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 5.0000003461985925e-23.
# 11/11 [==============================] - 1s 75ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 5.0000e-22
# Epoch 23/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0041 - mean_squared_error: 0.0041
# Epoch 23: val_loss did not improve from 0.38451
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 5.000000472416337e-24.
# 11/11 [==============================] - 1s 68ms/step - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 5.0000e-23
# Epoch 24/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 24: val_loss did not improve from 0.38451
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 5.000000393530247e-25.
# 11/11 [==============================] - 1s 60ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 5.0000e-24
# Epoch 25/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 25: val_loss did not improve from 0.38451
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 5.000000590745473e-26.
# 11/11 [==============================] - 1s 61ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 5.0000e-25
# Epoch 26/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0043 - mean_squared_error: 0.0043
# Epoch 26: val_loss did not improve from 0.38451
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 5.000000714004989e-27.
# 11/11 [==============================] - 1s 62ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 5.0000e-26
# Epoch 27/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 27: val_loss did not improve from 0.38451
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 5.00000071400499e-28.
# 11/11 [==============================] - 1s 63ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 5.0000e-27
# Epoch 28/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0045 - mean_squared_error: 0.0045
# Epoch 28: val_loss did not improve from 0.38451
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 5.000000617708492e-29.
# 11/11 [==============================] - 1s 64ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 5.0000e-28
# Epoch 29/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0042 - mean_squared_error: 0.0042
# Epoch 29: val_loss did not improve from 0.38451
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 5.0000006177084924e-30.
# 11/11 [==============================] - 1s 63ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 5.0000e-29
# Epoch 30/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 30: val_loss did not improve from 0.38451
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 5.0000007681717695e-31.
# 11/11 [==============================] - 1s 61ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 5.0000e-30
# Epoch 31/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0046 - mean_squared_error: 0.0046
# Epoch 31: val_loss did not improve from 0.38451
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 5.000000956250865e-32.
# 11/11 [==============================] - 1s 58ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 5.0000e-31
# Epoch 32/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0045 - mean_squared_error: 0.0045
# Epoch 32: val_loss did not improve from 0.38451
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 5.0000010738003005e-33.
# 11/11 [==============================] - 1s 56ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 5.0000e-32
# Epoch 33/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0041 - mean_squared_error: 0.0041
# Epoch 33: val_loss did not improve from 0.38451
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 5.000001220737094e-34.
# 11/11 [==============================] - 1s 58ms/step - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 5.0000e-33
# Epoch 34/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 34: val_loss did not improve from 0.38451
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 5.000001037066102e-35.
# 11/11 [==============================] - 1s 55ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 5.0000e-34
# Epoch 35/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0046 - mean_squared_error: 0.0046
# Epoch 35: val_loss did not improve from 0.38451
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 5.000000807477361e-36.
# 11/11 [==============================] - 1s 58ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 5.0000e-35
# Epoch 36/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 36: val_loss did not improve from 0.38451
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 5.000000807477361e-37.
# 11/11 [==============================] - 1s 60ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 5.0000e-36
# Epoch 37/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 37: val_loss did not improve from 0.38451
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 5.000000628111158e-38.
# 11/11 [==============================] - 1s 57ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 5.0000e-37
# Epoch 38/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 38: val_loss did not improve from 0.38451
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 5.000000516007281e-39.
# 11/11 [==============================] - 1s 58ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 5.0000e-38
# Epoch 39/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0045 - mean_squared_error: 0.0045
# Epoch 39: val_loss did not improve from 0.38451
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 5.000001076526666e-40.
# 11/11 [==============================] - 1s 55ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 5.0000e-39
# Epoch 40/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0043 - mean_squared_error: 0.0043
# Epoch 40: val_loss did not improve from 0.38451
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 5.000001076526667e-41.
# 11/11 [==============================] - 1s 59ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 5.0000e-40
# Epoch 41/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0045 - mean_squared_error: 0.0045
# Epoch 41: val_loss did not improve from 0.38451
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 4.99997305055738e-42.
# 11/11 [==============================] - 1s 57ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 5.0000e-41
# Epoch 42/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0045 - mean_squared_error: 0.0045
# Epoch 42: val_loss did not improve from 0.38451
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 4.9998329207109475e-43.
# 11/11 [==============================] - 1s 56ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 4.9998e-42
# Epoch 43/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 43: val_loss did not improve from 0.38451
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 5.002635517639597e-44.
# 11/11 [==============================] - 1s 61ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 5.0026e-43
# Epoch 44/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0042 - mean_squared_error: 0.0042
# Epoch 44: val_loss did not improve from 0.38451
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 5.0446744715693416e-45.
# 11/11 [==============================] - 1s 57ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 5.0447e-44
# Epoch 45/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0045 - mean_squared_error: 0.0045
# Epoch 45: val_loss did not improve from 0.38451
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 5.6051938572992686e-46.
# 11/11 [==============================] - 1s 55ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 5.6052e-45
# Epoch 46/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 46: val_loss did not improve from 0.38451
# 11/11 [==============================] - 1s 56ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 0.0000e+00
# Epoch 47/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0043 - mean_squared_error: 0.0043
# Epoch 47: val_loss did not improve from 0.38451
# 11/11 [==============================] - 1s 58ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 0.0000e+00
# Epoch 48/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0043 - mean_squared_error: 0.0043
# Epoch 48: val_loss did not improve from 0.38451
# 11/11 [==============================] - 1s 55ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 0.0000e+00
# Epoch 49/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 49: val_loss did not improve from 0.38451
# 11/11 [==============================] - 1s 55ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 0.0000e+00
# Epoch 50/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 50: val_loss did not improve from 0.38451
# 11/11 [==============================] - 1s 56ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 0.0000e+00
# Epoch 51/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0045 - mean_squared_error: 0.0045
# Epoch 51: val_loss did not improve from 0.38451
# 11/11 [==============================] - 1s 56ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 0.0000e+00
# Epoch 52/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0045 - mean_squared_error: 0.0045
# Epoch 52: val_loss did not improve from 0.38451
# 11/11 [==============================] - 1s 56ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 0.0000e+00
# Epoch 53/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0042 - mean_squared_error: 0.0042
# Epoch 53: val_loss did not improve from 0.38451
# 11/11 [==============================] - 1s 56ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 0.0000e+00
# Epoch 54/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0043 - mean_squared_error: 0.0043
# Epoch 54: val_loss did not improve from 0.38451
# 11/11 [==============================] - 1s 56ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 0.0000e+00
# Epoch 55/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 55: val_loss did not improve from 0.38451
# 11/11 [==============================] - 1s 56ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 0.0000e+00
# Epoch 56/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 56: val_loss did not improve from 0.38451
# 11/11 [==============================] - 1s 59ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 0.0000e+00
# Epoch 57/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 57: val_loss did not improve from 0.38451
# 11/11 [==============================] - 1s 56ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 0.0000e+00
# Epoch 58/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0043 - mean_squared_error: 0.0043
# Epoch 58: val_loss did not improve from 0.38451
# 11/11 [==============================] - 1s 61ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 0.0000e+00
# Epoch 59/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0043 - mean_squared_error: 0.0043
# Epoch 59: val_loss did not improve from 0.38451
# 11/11 [==============================] - 1s 57ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 0.0000e+00
# Epoch 60/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0043 - mean_squared_error: 0.0043
# Epoch 60: val_loss did not improve from 0.38451
# 11/11 [==============================] - 1s 56ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 0.0000e+00
# Epoch 61/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 61: val_loss did not improve from 0.38451
# 11/11 [==============================] - 1s 57ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 0.0000e+00
# Epoch 62/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0043 - mean_squared_error: 0.0043
# Epoch 62: val_loss did not improve from 0.38451
# 11/11 [==============================] - 1s 57ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 0.0000e+00
# Epoch 63/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 63: val_loss did not improve from 0.38451
# 11/11 [==============================] - 1s 57ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 0.0000e+00
# Epoch 64/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0043 - mean_squared_error: 0.0043
# Epoch 64: val_loss did not improve from 0.38451
# 11/11 [==============================] - 1s 57ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 0.0000e+00
# Epoch 65/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0042 - mean_squared_error: 0.0042
# Epoch 65: val_loss did not improve from 0.38451
# 11/11 [==============================] - 1s 59ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 0.0000e+00
# Epoch 66/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0043 - mean_squared_error: 0.0043
# Epoch 66: val_loss did not improve from 0.38451
# 11/11 [==============================] - 1s 56ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 0.0000e+00
# Epoch 67/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0046 - mean_squared_error: 0.0046
# Epoch 67: val_loss did not improve from 0.38451
# 11/11 [==============================] - 1s 55ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 0.0000e+00
# Epoch 68/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 68: val_loss did not improve from 0.38451
# 11/11 [==============================] - 1s 56ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 0.0000e+00
# Epoch 69/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0043 - mean_squared_error: 0.0043
# Epoch 69: val_loss did not improve from 0.38451
# 11/11 [==============================] - 1s 55ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 0.0000e+00
# Epoch 70/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0045 - mean_squared_error: 0.0045
# Epoch 70: val_loss did not improve from 0.38451
# 11/11 [==============================] - 1s 57ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 0.0000e+00
# Epoch 71/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0043 - mean_squared_error: 0.0043
# Epoch 71: val_loss did not improve from 0.38451
# 11/11 [==============================] - 1s 56ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 0.0000e+00
# Epoch 72/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0046 - mean_squared_error: 0.0046
# Epoch 72: val_loss did not improve from 0.38451
# 11/11 [==============================] - 1s 71ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 0.0000e+00
# Epoch 73/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0043 - mean_squared_error: 0.0043
# Epoch 73: val_loss did not improve from 0.38451
# 11/11 [==============================] - 1s 62ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 0.0000e+00
# Epoch 74/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 74: val_loss did not improve from 0.38451
# 11/11 [==============================] - 1s 59ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 0.0000e+00
# Epoch 75/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 75: val_loss did not improve from 0.38451
# 11/11 [==============================] - 1s 58ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 0.0000e+00
# Epoch 76/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0043 - mean_squared_error: 0.0043
# Epoch 76: val_loss did not improve from 0.38451
# 11/11 [==============================] - 1s 56ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 0.0000e+00
# Epoch 77/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0046 - mean_squared_error: 0.0046
# Epoch 77: val_loss did not improve from 0.38451
# 11/11 [==============================] - 1s 59ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 0.0000e+00
# Epoch 78/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0045 - mean_squared_error: 0.0045
# Epoch 78: val_loss did not improve from 0.38451
# 11/11 [==============================] - 1s 54ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 0.0000e+00
# Epoch 79/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 79: val_loss did not improve from 0.38451
# 11/11 [==============================] - 1s 56ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 0.0000e+00
# Epoch 80/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0041 - mean_squared_error: 0.0041
# Epoch 80: val_loss did not improve from 0.38451
# 11/11 [==============================] - 1s 56ms/step - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 0.0000e+00
# Epoch 81/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0043 - mean_squared_error: 0.0043
# Epoch 81: val_loss did not improve from 0.38451
# 11/11 [==============================] - 1s 56ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 0.0000e+00
# Epoch 82/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 82: val_loss did not improve from 0.38451
# 11/11 [==============================] - 1s 57ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 0.0000e+00
# Epoch 83/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 83: val_loss did not improve from 0.38451
# 11/11 [==============================] - 1s 56ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 0.0000e+00
# Epoch 84/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0043 - mean_squared_error: 0.0043
# Epoch 84: val_loss did not improve from 0.38451
# 11/11 [==============================] - 1s 55ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 0.0000e+00
# Epoch 85/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 85: val_loss did not improve from 0.38451
# 11/11 [==============================] - 1s 56ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 0.0000e+00
# Epoch 86/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0043 - mean_squared_error: 0.0043
# Epoch 86: val_loss did not improve from 0.38451
# 11/11 [==============================] - 1s 58ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 0.0000e+00
# Epoch 87/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0042 - mean_squared_error: 0.0042
# Epoch 87: val_loss did not improve from 0.38451
# 11/11 [==============================] - 1s 57ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 0.0000e+00
# Epoch 88/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0045 - mean_squared_error: 0.0045
# Epoch 88: val_loss did not improve from 0.38451
# 11/11 [==============================] - 1s 55ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 0.0000e+00
# Epoch 89/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0043 - mean_squared_error: 0.0043
# Epoch 89: val_loss did not improve from 0.38451
# 11/11 [==============================] - 1s 57ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 0.0000e+00
# Epoch 90/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0045 - mean_squared_error: 0.0045
# Epoch 90: val_loss did not improve from 0.38451
# 11/11 [==============================] - 1s 60ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 0.0000e+00
# Epoch 91/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 91: val_loss did not improve from 0.38451
# 11/11 [==============================] - 1s 56ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 0.0000e+00
# Epoch 92/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 92: val_loss did not improve from 0.38451
# 11/11 [==============================] - 1s 56ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 0.0000e+00
# Epoch 93/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0042 - mean_squared_error: 0.0042
# Epoch 93: val_loss did not improve from 0.38451
# 11/11 [==============================] - 1s 56ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 0.0000e+00
# Epoch 94/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0043 - mean_squared_error: 0.0043
# Epoch 94: val_loss did not improve from 0.38451
# 11/11 [==============================] - 1s 57ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 0.0000e+00
# Epoch 95/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0043 - mean_squared_error: 0.0043
# Epoch 95: val_loss did not improve from 0.38451
# 11/11 [==============================] - 1s 60ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 0.0000e+00
# Epoch 96/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 96: val_loss did not improve from 0.38451
# 11/11 [==============================] - 1s 55ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 0.0000e+00
# Epoch 97/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0042 - mean_squared_error: 0.0042
# Epoch 97: val_loss did not improve from 0.38451
# 11/11 [==============================] - 1s 58ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 0.0000e+00
# Epoch 98/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0042 - mean_squared_error: 0.0042
# Epoch 98: val_loss did not improve from 0.38451
# 11/11 [==============================] - 1s 65ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 0.0000e+00
# Epoch 99/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0042 - mean_squared_error: 0.0042
# Epoch 99: val_loss did not improve from 0.38451
# 11/11 [==============================] - 1s 56ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 0.0000e+00
# Epoch 100/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 100: val_loss did not improve from 0.38451
# 11/11 [==============================] - 1s 56ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 0.0000e+00
# Red - Predicted Stock Prices  ,  Blue - Actual Stock Prices
# Display Accuracy Training Data
# 0.9061991102837981
# Red - Predicted Stock Prices  ,  Blue - Actual Stock Prices
# Display Accuracy Training Data
# 0.9018799302503792
#             date symbol        open       close         low        high  \
# 0     12-04-2019   ADBE   37.330002   37.619999   37.200001   37.740002
# 1     07-01-2010   ADBE   37.410000   36.889999   36.810001   37.590000
# 2     08-01-2010   ADBE   36.750000   36.689999   36.340000   36.970001
# 3     11-01-2010   ADBE   36.680000   36.209999   35.950001   36.770000
# 4     12-01-2010   ADBE   36.139999   35.660000   35.380001   36.139999
# ...          ...    ...         ...         ...         ...         ...
# 1755  23-12-2016   ADBE  104.610001  105.019997  104.610001  105.419998
# 1756  27-12-2016   ADBE  105.000000  104.980003  104.860001  105.900002
# 1757  28-12-2016   ADBE  104.830002  103.769997  103.500000  105.160004
# 1758  29-12-2016   ADBE  103.629997  103.680000  103.410004  104.389999
# 1759  30-12-2016   ADBE  104.070000  102.949997  102.470001  104.220001
#
#        volume  Close_Prediction
# 0     5336400         39.672001
# 1     5576700         39.861126
# 2     5429200         39.594624
# 3     4901400         39.272079
# 4     5073900         39.045235
# ...       ...               ...
# 1755  1047500         88.630241
# 1756  1047400         88.425697
# 1757  1723500         88.530281
# 1758  1095000         88.073860
# 1759  2079100         87.561081
#
# [1760 rows x 8 columns]
# array([[0.04620402],
#        [0.04412031],
#        [0.05308933],
#        ...,
#        [0.85178473],
#        [0.84662075],
#        [0.8348433 ]])
# (806, 1)
# (202, 1)
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 6/7 [========================>.....] - ETA: 0s - loss: 0.1869 - mean_squared_error: 0.1869
# Epoch 1: val_loss improved from -inf to 0.56556, saving model to stock_weights1.hdf5
# 7/7 [==============================] - 13s 470ms/step - loss: 0.1862 - mean_squared_error: 0.1862 - val_loss: 0.5656 - val_mean_squared_error: 0.5656 - lr: 5.0000e-04
# Epoch 2/100
# 6/7 [========================>.....] - ETA: 0s - loss: 0.1149 - mean_squared_error: 0.1149
# Epoch 2: val_loss did not improve from 0.56556
# 7/7 [==============================] - 0s 58ms/step - loss: 0.1135 - mean_squared_error: 0.1135 - val_loss: 0.2881 - val_mean_squared_error: 0.2881 - lr: 5.0000e-04
# Epoch 3/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0374 - mean_squared_error: 0.0374
# Epoch 3: val_loss did not improve from 0.56556
# 7/7 [==============================] - 0s 56ms/step - loss: 0.0374 - mean_squared_error: 0.0374 - val_loss: 0.0347 - val_mean_squared_error: 0.0347 - lr: 5.0000e-04
# Epoch 4/100
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0167 - mean_squared_error: 0.0167
# Epoch 4: val_loss did not improve from 0.56556
# 7/7 [==============================] - 0s 65ms/step - loss: 0.0173 - mean_squared_error: 0.0173 - val_loss: 0.0013 - val_mean_squared_error: 0.0013 - lr: 5.0000e-04
# Epoch 5/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0169 - mean_squared_error: 0.0169
# Epoch 5: val_loss did not improve from 0.56556
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 5.0000002374872565e-05.
# 7/7 [==============================] - 0s 61ms/step - loss: 0.0169 - mean_squared_error: 0.0169 - val_loss: 0.0180 - val_mean_squared_error: 0.0180 - lr: 5.0000e-04
# Epoch 6/100
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0087 - mean_squared_error: 0.0087
# Epoch 6: val_loss did not improve from 0.56556
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 5.000000237487257e-06.
# 7/7 [==============================] - 0s 63ms/step - loss: 0.0087 - mean_squared_error: 0.0087 - val_loss: 0.0215 - val_mean_squared_error: 0.0215 - lr: 5.0000e-05
# Epoch 7/100
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0088 - mean_squared_error: 0.0088
# Epoch 7: val_loss did not improve from 0.56556
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 5.000000328436726e-07.
# 7/7 [==============================] - 0s 60ms/step - loss: 0.0087 - mean_squared_error: 0.0087 - val_loss: 0.0217 - val_mean_squared_error: 0.0217 - lr: 5.0000e-06
# Epoch 8/100
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0089 - mean_squared_error: 0.0089
# Epoch 8: val_loss did not improve from 0.56556
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 5.000000555810402e-08.
# 7/7 [==============================] - 0s 58ms/step - loss: 0.0089 - mean_squared_error: 0.0089 - val_loss: 0.0217 - val_mean_squared_error: 0.0217 - lr: 5.0000e-07
# Epoch 9/100
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0085 - mean_squared_error: 0.0085
# Epoch 9: val_loss did not improve from 0.56556
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 5.000000413701855e-09.
# 7/7 [==============================] - 0s 63ms/step - loss: 0.0085 - mean_squared_error: 0.0085 - val_loss: 0.0217 - val_mean_squared_error: 0.0217 - lr: 5.0000e-08
# Epoch 10/100
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0086 - mean_squared_error: 0.0086
# Epoch 10: val_loss did not improve from 0.56556
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 5.000000413701855e-10.
# 7/7 [==============================] - 0s 62ms/step - loss: 0.0086 - mean_squared_error: 0.0086 - val_loss: 0.0217 - val_mean_squared_error: 0.0217 - lr: 5.0000e-09
# Epoch 11/100
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0085 - mean_squared_error: 0.0085
# Epoch 11: val_loss did not improve from 0.56556
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 5.000000413701855e-11.
# 7/7 [==============================] - 0s 63ms/step - loss: 0.0085 - mean_squared_error: 0.0085 - val_loss: 0.0217 - val_mean_squared_error: 0.0217 - lr: 5.0000e-10
# Epoch 12/100
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0085 - mean_squared_error: 0.0085
# Epoch 12: val_loss did not improve from 0.56556
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 5.000000413701855e-12.
# 7/7 [==============================] - 0s 64ms/step - loss: 0.0085 - mean_squared_error: 0.0085 - val_loss: 0.0217 - val_mean_squared_error: 0.0217 - lr: 5.0000e-11
# Epoch 13/100
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0089 - mean_squared_error: 0.0089
# Epoch 13: val_loss did not improve from 0.56556
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 5.000000413701855e-13.
# 7/7 [==============================] - 0s 63ms/step - loss: 0.0088 - mean_squared_error: 0.0088 - val_loss: 0.0217 - val_mean_squared_error: 0.0217 - lr: 5.0000e-12
# Epoch 14/100
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0085 - mean_squared_error: 0.0085
# Epoch 14: val_loss did not improve from 0.56556
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 5.0000005221220725e-14.
# 7/7 [==============================] - 0s 62ms/step - loss: 0.0086 - mean_squared_error: 0.0086 - val_loss: 0.0217 - val_mean_squared_error: 0.0217 - lr: 5.0000e-13
# Epoch 15/100
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0085 - mean_squared_error: 0.0085
# Epoch 15: val_loss did not improve from 0.56556
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 5.000000589884709e-15.
# 7/7 [==============================] - 0s 64ms/step - loss: 0.0085 - mean_squared_error: 0.0085 - val_loss: 0.0217 - val_mean_squared_error: 0.0217 - lr: 5.0000e-14
# Epoch 16/100
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0087 - mean_squared_error: 0.0087
# Epoch 16: val_loss did not improve from 0.56556
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 5.000000759291298e-16.
# 7/7 [==============================] - 0s 62ms/step - loss: 0.0086 - mean_squared_error: 0.0086 - val_loss: 0.0217 - val_mean_squared_error: 0.0217 - lr: 5.0000e-15
# Epoch 17/100
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0087 - mean_squared_error: 0.0087
# Epoch 17: val_loss did not improve from 0.56556
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 5.000000547533061e-17.
# 7/7 [==============================] - 0s 59ms/step - loss: 0.0087 - mean_squared_error: 0.0087 - val_loss: 0.0217 - val_mean_squared_error: 0.0217 - lr: 5.0000e-16
# Epoch 18/100
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0090 - mean_squared_error: 0.0090
# Epoch 18: val_loss did not improve from 0.56556
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 5.000000415184163e-18.
# 7/7 [==============================] - 0s 65ms/step - loss: 0.0088 - mean_squared_error: 0.0088 - val_loss: 0.0217 - val_mean_squared_error: 0.0217 - lr: 5.0000e-17
# Epoch 19/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0085 - mean_squared_error: 0.0085
# Epoch 19: val_loss did not improve from 0.56556
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 5.000000332466102e-19.
# 7/7 [==============================] - 0s 52ms/step - loss: 0.0085 - mean_squared_error: 0.0085 - val_loss: 0.0217 - val_mean_squared_error: 0.0217 - lr: 5.0000e-18
# Epoch 20/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0089 - mean_squared_error: 0.0089
# Epoch 20: val_loss did not improve from 0.56556
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 5.000000229068525e-20.
# 7/7 [==============================] - 0s 64ms/step - loss: 0.0089 - mean_squared_error: 0.0089 - val_loss: 0.0217 - val_mean_squared_error: 0.0217 - lr: 5.0000e-19
# Epoch 21/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0089 - mean_squared_error: 0.0089
# Epoch 21: val_loss did not improve from 0.56556
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 5.00000016444504e-21.
# 7/7 [==============================] - 0s 56ms/step - loss: 0.0089 - mean_squared_error: 0.0089 - val_loss: 0.0217 - val_mean_squared_error: 0.0217 - lr: 5.0000e-20
# Epoch 22/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0088 - mean_squared_error: 0.0088
# Epoch 22: val_loss did not improve from 0.56556
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 5.000000245224397e-22.
# 7/7 [==============================] - 0s 59ms/step - loss: 0.0088 - mean_squared_error: 0.0088 - val_loss: 0.0217 - val_mean_squared_error: 0.0217 - lr: 5.0000e-21
# Epoch 23/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0089 - mean_squared_error: 0.0089
# Epoch 23: val_loss did not improve from 0.56556
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 5.0000003461985925e-23.
# 7/7 [==============================] - 0s 57ms/step - loss: 0.0089 - mean_squared_error: 0.0089 - val_loss: 0.0217 - val_mean_squared_error: 0.0217 - lr: 5.0000e-22
# Epoch 24/100
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0087 - mean_squared_error: 0.0087
# Epoch 24: val_loss did not improve from 0.56556
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 5.000000472416337e-24.
# 7/7 [==============================] - 0s 59ms/step - loss: 0.0087 - mean_squared_error: 0.0087 - val_loss: 0.0217 - val_mean_squared_error: 0.0217 - lr: 5.0000e-23
# Epoch 25/100
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0089 - mean_squared_error: 0.0089
# Epoch 25: val_loss did not improve from 0.56556
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 5.000000393530247e-25.
# 7/7 [==============================] - 0s 63ms/step - loss: 0.0088 - mean_squared_error: 0.0088 - val_loss: 0.0217 - val_mean_squared_error: 0.0217 - lr: 5.0000e-24
# Epoch 26/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0084 - mean_squared_error: 0.0084
# Epoch 26: val_loss did not improve from 0.56556
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 5.000000590745473e-26.
# 7/7 [==============================] - 0s 58ms/step - loss: 0.0084 - mean_squared_error: 0.0084 - val_loss: 0.0217 - val_mean_squared_error: 0.0217 - lr: 5.0000e-25
# Epoch 27/100
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0085 - mean_squared_error: 0.0085
# Epoch 27: val_loss did not improve from 0.56556
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 5.000000714004989e-27.
# 7/7 [==============================] - 0s 54ms/step - loss: 0.0085 - mean_squared_error: 0.0085 - val_loss: 0.0217 - val_mean_squared_error: 0.0217 - lr: 5.0000e-26
# Epoch 28/100
# 6/7 [========================>.....] - ETA: 0s - loss: 0.0086 - mean_squared_error: 0.0086
# Epoch 28: val_loss did not improve from 0.56556
#
# ...
# Epoch 56/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0090 - mean_squared_error: 0.0090
# Epoch 56: val_loss did not improve from 0.15577
# 11/11 [==============================] - 1s 52ms/step - loss: 0.0090 - mean_squared_error: 0.0090 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - lr: 0.0000e+00
# Epoch 57/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0089 - mean_squared_error: 0.0089
# Epoch 57: val_loss did not improve from 0.15577
# 11/11 [==============================] - 1s 51ms/step - loss: 0.0089 - mean_squared_error: 0.0089 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - lr: 0.0000e+00
# Epoch 58/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0087 - mean_squared_error: 0.0087
# Epoch 58: val_loss did not improve from 0.15577
# 11/11 [==============================] - 1s 53ms/step - loss: 0.0088 - mean_squared_error: 0.0088 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - lr: 0.0000e+00
# Epoch 59/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0089 - mean_squared_error: 0.0089
# Epoch 59: val_loss did not improve from 0.15577
# 11/11 [==============================] - 1s 52ms/step - loss: 0.0089 - mean_squared_error: 0.0089 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - lr: 0.0000e+00
# Epoch 60/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0089 - mean_squared_error: 0.0089
# Epoch 60: val_loss did not improve from 0.15577
# 11/11 [==============================] - 1s 53ms/step - loss: 0.0089 - mean_squared_error: 0.0089 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - lr: 0.0000e+00
# Epoch 61/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0088 - mean_squared_error: 0.0088
# Epoch 61: val_loss did not improve from 0.15577
# 11/11 [==============================] - 1s 53ms/step - loss: 0.0088 - mean_squared_error: 0.0088 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - lr: 0.0000e+00
# Epoch 62/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0089 - mean_squared_error: 0.0089
# Epoch 62: val_loss did not improve from 0.15577
# 11/11 [==============================] - 1s 52ms/step - loss: 0.0089 - mean_squared_error: 0.0089 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - lr: 0.0000e+00
# Epoch 63/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0089 - mean_squared_error: 0.0089
# Epoch 63: val_loss did not improve from 0.15577
# 11/11 [==============================] - 1s 53ms/step - loss: 0.0089 - mean_squared_error: 0.0089 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - lr: 0.0000e+00
# Epoch 64/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0091 - mean_squared_error: 0.0091
# Epoch 64: val_loss did not improve from 0.15577
# 11/11 [==============================] - 1s 51ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - lr: 0.0000e+00
# Epoch 65/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0087 - mean_squared_error: 0.0087
# Epoch 65: val_loss did not improve from 0.15577
# 11/11 [==============================] - 1s 51ms/step - loss: 0.0087 - mean_squared_error: 0.0087 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - lr: 0.0000e+00
# Epoch 66/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0089 - mean_squared_error: 0.0089
# Epoch 66: val_loss did not improve from 0.15577
# 11/11 [==============================] - 1s 51ms/step - loss: 0.0088 - mean_squared_error: 0.0088 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - lr: 0.0000e+00
# Epoch 67/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0090 - mean_squared_error: 0.0090
# Epoch 67: val_loss did not improve from 0.15577
# 11/11 [==============================] - 1s 51ms/step - loss: 0.0090 - mean_squared_error: 0.0090 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - lr: 0.0000e+00
# Epoch 68/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0090 - mean_squared_error: 0.0090
# Epoch 68: val_loss did not improve from 0.15577
# 11/11 [==============================] - 1s 50ms/step - loss: 0.0090 - mean_squared_error: 0.0090 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - lr: 0.0000e+00
# Epoch 69/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0088 - mean_squared_error: 0.0088
# Epoch 69: val_loss did not improve from 0.15577
# 11/11 [==============================] - 1s 52ms/step - loss: 0.0088 - mean_squared_error: 0.0088 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - lr: 0.0000e+00
# Epoch 70/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0090 - mean_squared_error: 0.0090
# Epoch 70: val_loss did not improve from 0.15577
# 11/11 [==============================] - 1s 49ms/step - loss: 0.0090 - mean_squared_error: 0.0090 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - lr: 0.0000e+00
# Epoch 71/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0089 - mean_squared_error: 0.0089
# Epoch 71: val_loss did not improve from 0.15577
# 11/11 [==============================] - 1s 51ms/step - loss: 0.0089 - mean_squared_error: 0.0089 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - lr: 0.0000e+00
# Epoch 72/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0089 - mean_squared_error: 0.0089
# Epoch 72: val_loss did not improve from 0.15577
# 11/11 [==============================] - 1s 50ms/step - loss: 0.0089 - mean_squared_error: 0.0089 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - lr: 0.0000e+00
# Epoch 73/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0092 - mean_squared_error: 0.0092
# Epoch 73: val_loss did not improve from 0.15577
# 11/11 [==============================] - 1s 50ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - lr: 0.0000e+00
# Epoch 74/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0090 - mean_squared_error: 0.0090
# Epoch 74: val_loss did not improve from 0.15577
# 11/11 [==============================] - 1s 51ms/step - loss: 0.0090 - mean_squared_error: 0.0090 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - lr: 0.0000e+00
# Epoch 75/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0090 - mean_squared_error: 0.0090
# Epoch 75: val_loss did not improve from 0.15577
# 11/11 [==============================] - 1s 51ms/step - loss: 0.0090 - mean_squared_error: 0.0090 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - lr: 0.0000e+00
# Epoch 76/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0087 - mean_squared_error: 0.0087
# Epoch 76: val_loss did not improve from 0.15577
# 11/11 [==============================] - 1s 51ms/step - loss: 0.0087 - mean_squared_error: 0.0087 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - lr: 0.0000e+00
# Epoch 77/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0088 - mean_squared_error: 0.0088
# Epoch 77: val_loss did not improve from 0.15577
# 11/11 [==============================] - 1s 51ms/step - loss: 0.0089 - mean_squared_error: 0.0089 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - lr: 0.0000e+00
# Epoch 78/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0090 - mean_squared_error: 0.0090
# Epoch 78: val_loss did not improve from 0.15577
# 11/11 [==============================] - 1s 52ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - lr: 0.0000e+00
# Epoch 79/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0090 - mean_squared_error: 0.0090
# Epoch 79: val_loss did not improve from 0.15577
# 11/11 [==============================] - 1s 52ms/step - loss: 0.0090 - mean_squared_error: 0.0090 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - lr: 0.0000e+00
# Epoch 80/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0090 - mean_squared_error: 0.0090
# Epoch 80: val_loss did not improve from 0.15577
# 11/11 [==============================] - 1s 51ms/step - loss: 0.0089 - mean_squared_error: 0.0089 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - lr: 0.0000e+00
# Epoch 81/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0089 - mean_squared_error: 0.0089
# Epoch 81: val_loss did not improve from 0.15577
# 11/11 [==============================] - 1s 51ms/step - loss: 0.0090 - mean_squared_error: 0.0090 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - lr: 0.0000e+00
# Epoch 82/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0088 - mean_squared_error: 0.0088
# Epoch 82: val_loss did not improve from 0.15577
# 11/11 [==============================] - 1s 52ms/step - loss: 0.0088 - mean_squared_error: 0.0088 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - lr: 0.0000e+00
# Epoch 83/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0089 - mean_squared_error: 0.0089
# Epoch 83: val_loss did not improve from 0.15577
# 11/11 [==============================] - 1s 51ms/step - loss: 0.0089 - mean_squared_error: 0.0089 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - lr: 0.0000e+00
# Epoch 84/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0091 - mean_squared_error: 0.0091
# Epoch 84: val_loss did not improve from 0.15577
# 11/11 [==============================] - 1s 52ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - lr: 0.0000e+00
# Epoch 85/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0086 - mean_squared_error: 0.0086
# Epoch 85: val_loss did not improve from 0.15577
# 11/11 [==============================] - 1s 58ms/step - loss: 0.0086 - mean_squared_error: 0.0086 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - lr: 0.0000e+00
# Epoch 86/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0091 - mean_squared_error: 0.0091
# Epoch 86: val_loss did not improve from 0.15577
# 11/11 [==============================] - 1s 51ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - lr: 0.0000e+00
# Epoch 87/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0090 - mean_squared_error: 0.0090
# Epoch 87: val_loss did not improve from 0.15577
# 11/11 [==============================] - 1s 51ms/step - loss: 0.0090 - mean_squared_error: 0.0090 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - lr: 0.0000e+00
# Epoch 88/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0093 - mean_squared_error: 0.0093
# Epoch 88: val_loss did not improve from 0.15577
# 11/11 [==============================] - 1s 56ms/step - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - lr: 0.0000e+00
# Epoch 89/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0090 - mean_squared_error: 0.0090
# Epoch 89: val_loss did not improve from 0.15577
# 11/11 [==============================] - 1s 51ms/step - loss: 0.0090 - mean_squared_error: 0.0090 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - lr: 0.0000e+00
# Epoch 90/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0089 - mean_squared_error: 0.0089
# Epoch 90: val_loss did not improve from 0.15577
# 11/11 [==============================] - 1s 51ms/step - loss: 0.0089 - mean_squared_error: 0.0089 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - lr: 0.0000e+00
# Epoch 91/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0088 - mean_squared_error: 0.0088
# Epoch 91: val_loss did not improve from 0.15577
# 11/11 [==============================] - 1s 59ms/step - loss: 0.0089 - mean_squared_error: 0.0089 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - lr: 0.0000e+00
# Epoch 92/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0089 - mean_squared_error: 0.0089
# Epoch 92: val_loss did not improve from 0.15577
# 11/11 [==============================] - 1s 52ms/step - loss: 0.0090 - mean_squared_error: 0.0090 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - lr: 0.0000e+00
# Epoch 93/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0088 - mean_squared_error: 0.0088
# Epoch 93: val_loss did not improve from 0.15577
# 11/11 [==============================] - 1s 53ms/step - loss: 0.0088 - mean_squared_error: 0.0088 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - lr: 0.0000e+00
# Epoch 94/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0090 - mean_squared_error: 0.0090
# Epoch 94: val_loss did not improve from 0.15577
# 11/11 [==============================] - 1s 53ms/step - loss: 0.0090 - mean_squared_error: 0.0090 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - lr: 0.0000e+00
# Epoch 95/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0091 - mean_squared_error: 0.0091
# Epoch 95: val_loss did not improve from 0.15577
# 11/11 [==============================] - 1s 53ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - lr: 0.0000e+00
# Epoch 96/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0087 - mean_squared_error: 0.0087
# Epoch 96: val_loss did not improve from 0.15577
# 11/11 [==============================] - 1s 49ms/step - loss: 0.0087 - mean_squared_error: 0.0087 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - lr: 0.0000e+00
# Epoch 97/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0090 - mean_squared_error: 0.0090
# Epoch 97: val_loss did not improve from 0.15577
# 11/11 [==============================] - 1s 51ms/step - loss: 0.0090 - mean_squared_error: 0.0090 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - lr: 0.0000e+00
# Epoch 98/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0093 - mean_squared_error: 0.0093
# Epoch 98: val_loss did not improve from 0.15577
# 11/11 [==============================] - 1s 51ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - lr: 0.0000e+00
# Epoch 99/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0090 - mean_squared_error: 0.0090
# Epoch 99: val_loss did not improve from 0.15577
# 11/11 [==============================] - 1s 50ms/step - loss: 0.0090 - mean_squared_error: 0.0090 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - lr: 0.0000e+00
# Epoch 100/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0090 - mean_squared_error: 0.0090
# Epoch 100: val_loss did not improve from 0.15577
# 11/11 [==============================] - 1s 52ms/step - loss: 0.0090 - mean_squared_error: 0.0090 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - lr: 0.0000e+00
# Red - Predicted Stock Prices  ,  Blue - Actual Stock Prices
# Display Accuracy Training Data
# 0.8982515414476381
# Red - Predicted Stock Prices  ,  Blue - Actual Stock Prices
# Display Accuracy Training Data
# 0.9073193947923319
#             date symbol       open      close        low       high    volume  \
# 0     06-01-2010   YHOO  17.170000  17.170000  17.070000  17.299999  16422000
# 1     07-01-2010   YHOO  16.809999  16.700001  16.570000  16.900000  31816300
# 2     08-01-2010   YHOO  16.680000  16.700001  16.620001  16.760000  15470000
# 3     11-01-2010   YHOO  16.770000  16.740000  16.480000  16.830000  16181900
# 4     12-01-2010   YHOO  16.650000  16.680000  16.600000  16.860001  15672400
# ...          ...    ...        ...        ...        ...        ...       ...
# 1755  23-12-2016   YHOO  38.459999  38.660000  38.369999  38.810001   3840100
# 1756  27-12-2016   YHOO  38.590000  38.919998  38.500000  39.070000   4240300
# 1757  28-12-2016   YHOO  39.119999  38.730000  38.709999  39.220001   4393500
# 1758  29-12-2016   YHOO  38.759998  38.639999  38.480000  38.930000   4170200
# 1759  30-12-2016   YHOO  38.720001  38.669998  38.430000  39.000000   6431600
#
#       Close_Prediction
# 0            20.787210
# 1            20.811598
# 2            20.632509
# 3            20.471363
# 4            20.484835
# ...                ...
# 1755         36.014980
# 1756         35.834534
# 1757         35.986019
# 1758         36.013142
# 1759         35.911469
#
# [1760 rows x 8 columns]
